# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
import os
from skimage.io import imread_collection
from skimage import data, img_as_float, io, exposure
import matplotlib
from natsort import natsorted, ns
import warnings
warnings.simplefilter("ignore")
import pandas as pd
# from fastai.vision.all import *

# %%
# listFiles = os.listdir('train_v2')
# listFiles = natsorted(listFiles)
# allImages = []
# for filename in listFiles:
#     temp = os.path.join('train_v2',filename)
#     allImages.append(io.imread(temp))

# %%
# from sklearn.model_selection import train_test_split
import pandas as pd
# train_names = [f for f in os.listdir("train_v2")]
train_names = [f for f in os.listdir("Train_Ship_New/")]
# tr_n, val_n = train_test_split(train_names, test_size=0.05, random_state=42)

# segmentation_df = pd.read_csv(os.path.join('./', './train_ship_segmentations_v2.csv')
# segmentation_df = pd.read_csv('train_ship_segmentations_v2.csv')

# %%
# segmentation_df
strOne = "Val_Ship_New/0bca5cdb7.jpg"
novelImage = io.imread(strOne)
io.imshow(novelImage)
# print(train_names[1])

# %%
from skimage import color
convertImage = color.hsv2rgb(novelImage)
convertImage = color.rgb2gray(convertImage)
# for i in convertImage:
#     print(i)
# convertImage[0].shape
io.imshow(convertImage)

# %%
temp = 0
thresh = 0.2
finalImage = []
for i in range(768):
    newRow = []
    tempRow = convertImage[i]
    segOne = tempRow[0:256]
    segTwo = tempRow[256:512]
    segThree = tempRow[512:]
    calcThree = max(segThree) - min(segThree)
    calcOne = max(segOne) - min(segOne)
    calcTwo = max(segTwo) - min(segTwo)
    if(calcOne < thresh):
        segOne = [0 for j in range(256)]
    if(calcTwo < thresh):
        segTwo = [0 for j in range(256)]
    if(calcThree < thresh):
        segThree = [0 for j in range(256)]
    for j in segOne:
        newRow.append(j)
    for j in segTwo:
        newRow.append(j)
    for j in segThree:
        newRow.append(j)
    finalImage.append(newRow)
#     print(temp)
# temp
# print(calcOne, calcTwo, calcThree)
# finalImage = segOne + segTwo + segThree
# finalImage
# finalImage

# %%
from skimage.transform import resize
# io.imshow(np.array(finalImage))
pleaseWork = np.array(finalImage)
io.imshow(pleaseWork)
# io.imshow(resize(pleaseWork, (128,128)))

# %%
import cv2 as cv
from skimage.transform import rescale
# novelImage = rescale(novelImage, (128,128))
c1,c2,c3 = cv.split(novelImage)

# %%
temp = 0
thresh = 50
finalImage = []
for i in range(768):
    newRow = []
    tempRow = c1[i]
    segOne = tempRow[0:256]
    segTwo = tempRow[256:512]
    segThree = tempRow[512:]
    calcThree = max(segThree) - min(segThree)
    calcOne = max(segOne) - min(segOne)
    calcTwo = max(segTwo) - min(segTwo)
    if(calcOne < thresh):
        segOne = [0 for j in range(256)]
    if(calcTwo < thresh):
        segTwo = [0 for j in range(256)]
    if(calcThree < thresh):
        segThree = [0 for j in range(256)]
    for j in segOne:
        newRow.append(j)
    for j in segTwo:
        newRow.append(j)
    for j in segThree:
        newRow.append(j)
    finalImage.append(newRow)
# print(calcOne, calcTwo, calcThree)

# %%
temp = 0
thresh = 50
finalImageTwo = []
for i in range(768):
    newRow = []
    tempRow = c2[i]
    segOne = tempRow[0:256]
    segTwo = tempRow[256:512]
    segThree = tempRow[512:]
    calcThree = max(segThree) - min(segThree)
    calcOne = max(segOne) - min(segOne)
    calcTwo = max(segTwo) - min(segTwo)
    if(calcOne < thresh):
        segOne = [0 for j in range(256)]
    if(calcTwo < thresh):
        segTwo = [0 for j in range(256)]
    if(calcThree < thresh):
        segThree = [0 for j in range(256)]
    for j in segOne:
        newRow.append(j)
    for j in segTwo:
        newRow.append(j)
    for j in segThree:
        newRow.append(j)
    finalImageTwo.append(newRow)
# print(calcOne, calcTwo, calcThree)

# %%
temp = 0
thresh = 50
finalImageThree = []
for i in range(768):
    newRow = []
    tempRow = c3[i]
    segOne = tempRow[0:256]
    segTwo = tempRow[256:512]
    segThree = tempRow[512:]
    calcThree = max(segThree) - min(segThree)
    calcOne = max(segOne) - min(segOne)
    calcTwo = max(segTwo) - min(segTwo)
    if(calcOne < thresh):
        segOne = [0 for j in range(256)]
    if(calcTwo < thresh):
        segTwo = [0 for j in range(256)]
    if(calcThree < thresh):
        segThree = [0 for j in range(256)]
    for j in segOne:
        newRow.append(j)
    for j in segTwo:
        newRow.append(j)
    for j in segThree:
        newRow.append(j)
    finalImageThree.append(newRow)
# print(calcOne, calcTwo, calcThree)

# %%
io.imshow(novelImage)

# %%
from PIL import Image
# img1 = Image.fromarray(np.array(finalImage)).convert('L')
# img2 = Image.fromarray(np.array(finalImageTwo)).convert('L')
# img3 = Image.fromarray(np.array(finalImageThree)).convert('L')
# convertedImage = Image.merge("RGB",(img1,img2,img3))
# convertedImage.show()
# io.imshow(convertedImage)

# %%
# from skimage.transform import resize
# thresh = 0.2
# for name in train_names:
#     str1 = 'Train_Ship_New/' + name
#     img = Image.open(str1)
# #     img = img.resize(img, (128,128))
#     resizeImg = resize(np.array(img), (128,128))
# #     img = img.open(img)
#     img = Image.fromarray(resizeImg, 'RGB')
#     red, green, blue = img.split()
#     red = np.array(red)
#     green = np.array(green)
#     blue = np.array(blue)
# #     print(red)
# #     red = resize(red, (128,128))
# #     blue = resize(blue, (128,128))
# #     green = resize(green, (128,128))
    
#     finalImageR = []
#     finalImageG = []
#     finalImageB = []
#     for i in range(128):
#         newRow = []
#         tempRow = red[i]
#         start = 0
#         end = 64
#         for j in range(2):
#             end = 64*(j+1)
#             segment = tempRow[start:end]
#             start = end
#             calc = max(segment) - min(segment)
# #         calcOne = max(segOne) - min(segOne)
# #         calcTwo = max(segTwo) - min(segTwo)
#             if(calc < thresh):
#                 segment = [0 for k in range(64)]
# #         if(calcTwo < thresh):
# #             segTwo = [0 for j in range(256)]
# #         if(calcThree < thresh):
# #             segThree = [0 for j in range(256)]
#             for k in segment:
#                 newRow.append(k)
# #         for j in segTwo:
# #             newRow.append(j)
# #         for j in segThree:
# #             newRow.append(j)
#         finalImageR.append(newRow)
#     for i in range(128):
#         newRow = []
#         tempRow = green[i]
#         start = 0
#         end = 64
#         for j in range(2):
#             end = 64*(j+1)
#             segment = tempRow[start:end]
#             start = end
#             calc = max(segment) - min(segment)
# #         calcOne = max(segOne) - min(segOne)
# #         calcTwo = max(segTwo) - min(segTwo)
#             if(calc < thresh):
#                 segment = [0 for k in range(64)]
# #         if(calcTwo < thresh):
# #             segTwo = [0 for j in range(256)]
# #         if(calcThree < thresh):
# #             segThree = [0 for j in range(256)]
#             for k in segment:
#                 newRow.append(k)
# #         for j in segTwo:
# #             newRow.append(j)
# #         for j in segThree:
# #             newRow.append(j)
#         finalImageG.append(newRow)
#     for i in range(128):
#         newRow = []
#         tempRow = blue[i]
#         start = 0
#         end = 64
#         for j in range(2):
#             end = 64*(j+1)
#             segment = tempRow[start:end]
#             start = end
#             calc = max(segment) - min(segment)
# #         calcOne = max(segOne) - min(segOne)
# #         calcTwo = max(segTwo) - min(segTwo)
#             if(calc < thresh):
#                 segment = [0 for k in range(64)]
# #         if(calcTwo < thresh):
# #             segTwo = [0 for j in range(256)]
# #         if(calcThree < thresh):
# #             segThree = [0 for j in range(256)]
#             for k in segment:
#                 newRow.append(k)
# #         for j in segTwo:
# #             newRow.append(j)
# #         for j in segThree:
# #             newRow.append(j)
#         finalImageB.append(newRow)
#     img1 = Image.fromarray(np.array(finalImageR)).convert('L')
#     img2 = Image.fromarray(np.array(finalImageG)).convert('L')
#     img3 = Image.fromarray(np.array(finalImageB)).convert('L')
#     convertedImage = Image.merge("RGB",(img1,img2,img3))
#     convertedImage = np.array(convertedImage)
#     io.imsave("New_Train_Resize/{}".format(name), convertedImage)
# #     break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15200/2678680430.py in <module>
#       5     img = Image.open(str1)
#       6 #     img = img.resize(img, (128,128))
# ----> 7     resizeImg = resize(np.array(img), (128,128))
#       8 #     img = img.open(img)
#       9     img = Image.fromarray(resizeImg, 'RGB')
#
# D:\Anaconda\lib\site-packages\skimage\transform\_warps.py in resize(image, output_shape, order, mode, cval, clip, preserve_range, anti_aliasing, anti_aliasing_sigma)
#     145                              "documentation of numpy.pad for more info.")
#     146
# --> 147         image = ndi.gaussian_filter(image, anti_aliasing_sigma,
#     148                                     cval=cval, mode=ndi_mode)
#     149
#
# ...

# %%
thresh = 50
for name in train_names:
    str1 = 'Train_Ship_New/' + name
    img = Image.open(str1)
    red, green, blue = img.split()
    red = np.array(red)
    green = np.array(green)
    blue = np.array(blue)
    
    finalImageR = []
    finalImageG = []
    finalImageB = []
    for i in range(768):
        newRow = []
        tempRow = red[i]
        start = 0
        end = 128
        for j in range(6):
            end = 128*(j+1)
            segment = tempRow[start:end]
            start = end
            calc = max(segment) - min(segment)
#         calcOne = max(segOne) - min(segOne)
#         calcTwo = max(segTwo) - min(segTwo)
            if(calc < thresh):
                segment = [0 for k in range(128)]
#         if(calcTwo < thresh):
#             segTwo = [0 for j in range(256)]
#         if(calcThree < thresh):
#             segThree = [0 for j in range(256)]
            for k in segment:
                newRow.append(k)
#         for j in segTwo:
#             newRow.append(j)
#         for j in segThree:
#             newRow.append(j)
        finalImageR.append(newRow)
    for i in range(768):
        newRow = []
        tempRow = green[i]
        start = 0
        end = 128
        for j in range(6):
            end = 128*(j+1)
            segment = tempRow[start:end]
            start = end
            calc = max(segment) - min(segment)
#         calcOne = max(segOne) - min(segOne)
#         calcTwo = max(segTwo) - min(segTwo)
            if(calc < thresh):
                segment = [0 for k in range(128)]
#         if(calcTwo < thresh):
#             segTwo = [0 for j in range(256)]
#         if(calcThree < thresh):
#             segThree = [0 for j in range(256)]
            for k in segment:
                newRow.append(k)
#         for j in segTwo:
#             newRow.append(j)
#         for j in segThree:
#             newRow.append(j)
        finalImageG.append(newRow)
    for i in range(768):
        newRow = []
        tempRow = blue[i]
        start = 0
        end = 128
        for j in range(6):
            end = 128*(j+1)
            segment = tempRow[start:end]
            start = end
            calc = max(segment) - min(segment)
#         calcOne = max(segOne) - min(segOne)
#         calcTwo = max(segTwo) - min(segTwo)
            if(calc < thresh):
                segment = [0 for k in range(128)]
#         if(calcTwo < thresh):
#             segTwo = [0 for j in range(256)]
#         if(calcThree < thresh):
#             segThree = [0 for j in range(256)]
            for k in segment:
                newRow.append(k)
#         for j in segTwo:
#             newRow.append(j)
#         for j in segThree:
#             newRow.append(j)
        finalImageB.append(newRow)
    img1 = Image.fromarray(np.array(finalImageR)).convert('L')
    img2 = Image.fromarray(np.array(finalImageG)).convert('L')
    img3 = Image.fromarray(np.array(finalImageB)).convert('L')
    convertedImage = Image.merge("RGB",(img1,img2,img3))
    convertedImage = np.array(convertedImage)
    io.imsave("New_Train/{}".format(name), convertedImage)

# %%
trainAllImages = set()
for i in range(len(segmentation_df)):
    temp = segmentation_df.loc[i]["EncodedPixels"]
    if(type(temp)==str):
        trainAllImages.add(segmentation_df.loc[i]["ImageId"])
# print(trainAllImages[0])

# import math
# # newSeg = pd.read_csv(os.path.join(PATH, SEGMENTATION))
# # print(newSeg.iloc[0]['ImageId'])
# # segDict = dict()
# # print(newSeg.head)
# for i in range(len(segmentation_df)):
#     temp = segmentation_df.iloc[i]['EncodedPixels']
#     # print(temp)
#     if(type(temp)==str):
#         trainAllImages.add(segmentation_df.iloc[i]['ImageId'])
# print(len(trainAllImages))

# %%
newImages = list(trainAllImages)
len(newImages)
# Out:
# 42556

# %%
# len(listFiles)
newImages[0]
# Out:
# '7250e01bf.jpg'

# %%
from skimage.color import rgb2hsv
from skimage import transform
from skimage import filters

# %%
# from skimage import transform
# from skimage import filters
# trainImages = natsorted(trainAllImages)
# imagesList = []
count = 42556
count2 = 42565
# len(newImages)
for i in range(len(remainingImg)):
    # temp1 = os.path.join('train_v2',trainImages[i])
#     temp1 = os.path.join('../IMAGE-PROCESSING-Main/train_v2',trainImages[i])
    string = "train_v2/"+remainingImg[i]
    tempImage = io.imread(string)
    tempImage = rgb2hsv(tempImage)
    smoothingResult = filters.gaussian(tempImage,sigma = 0.9)
#     edgesResult = filters.sobel(smoothingResult)
    io.imsave("Ships/{}".format(remainingImg[i]), smoothingResult)
#     tempImage = transform.resize(tempImage,(128,128))
#   allImages.append(io.imread(temp))
#     imagesList.append(tempImage)
# Out:
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# ...

# %%
smoothingResult.shape
# Out:
# (768, 768, 3)

# %%
# print(imagesList[1])

# %%
# from skimage import filters
# smoothenedImages = []
# # smooothingResult = filters.gaussian(imagesList[1], sigma=1)
# # io.imshow(smooothingResult)
# for i in imagesList:
#     smoothingResult = filters.gaussian(i,sigma = 0.5)
#     smoothenedImages.append(smoothingResult)

# %%
# io.imshow(imagesList[1])

# %%
# imagesEdges = []
# for i in smoothenedImages:
#     edgesResult = filters.sobel(i)
#     imagesEdges.append(edgesResult)
#     io.imsave("smoothened/{}".format(trainImages[count]), edgesResult)
#     count+=1

# %%
# io.imshow(imagesEdges[1])

# %%
# import pandas as pd
# train_names = [f for f in os.listdir("train_v2")]
train_names = [f for f in os.listdir("Ships")]

# %%
data = pd.read_csv("prep_data.csv")
data.head()
# Out:
#          ImageId                                              Ship1  \
# 0  000155de5.jpg  264661 17 265429 33 266197 33 266965 33 267733...
# 1  000194a2d.jpg  360486 1 361252 4 362019 5 362785 8 363552 10 ...
# 2  00021ddc3.jpg  108287 1 109054 3 109821 4 110588 5 111356 5 1...
# 3  0002756f7.jpg  255784 2 256552 4 257319 7 258087 9 258854 12 ...
# 4  00031f145.jpg  340363 1 341129 4 341896 6 342663 7 343429 10 ...
#
#                                                Ship2  \
# 0                                                NaN
# 1  51834 9 52602 9 53370 9 54138 9 54906 9 55674 ...
# 2  101361 1 102128 3 102896 4 103663 6 104430 9 1...
# 3  248878 1 249645 4 250413 6 251180 9 251948 10 ...
# 4                                                NaN
#
#                                                Ship3  \
# 0                                                NaN
# 1  198320 10 199088 10 199856 10 200624 10 201392...
# 2  74441 3 75207 5 75975 5 76743 5 77511 5 78280 ...
# ...

# %%
allNames = list(data['ImageId'])
setAns = set(allNames) - set(train_names)
from natsort import natsorted
remainingImg = natsorted(list(setAns))
